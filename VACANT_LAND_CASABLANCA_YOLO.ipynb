# %%
# Installer la librairie Ultralytics (YOLOv8)
# !pip install ultralytics
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 922.2/922.2 kB 21.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 3.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 40.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 22.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 30.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 5.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 11.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 7.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 5.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 62.8 MB/s eta 0:00:00
# ...
#   Attempting uninstall: nvidia-nvjitlink-cu12
# ...

# %%
# Monter Google Drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
from ultralytics import YOLO

# Charger le modèle YOLOv8 pré-entraîné
model = YOLO('yolov8n-seg.pt')
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
# ...
# 100%|██████████| 6.74M/6.74M [00:00<00:00, 91.2MB/s]

# %%
# !yolo task=segment mode=train model="/content/drive/MyDrive/YOLO_D/yolov8n-seg.pt" \
    data="/content/drive/MyDrive/YOLO_D/data.yaml" \
    epochs=10 imgsz=640 batch=16
# Out:
# Ultralytics 8.3.85 🚀 Python-3.11.11 torch-2.5.1+cu124 CUDA:0 (Tesla T4, 15095MiB)
# ...

# %%
# !yolo task=segment mode=train model=yolov8s-seg.pt data=/content/drive/MyDrive/YOLO_D/data.yaml epochs=50 batch=8 imgsz=960
# Out:
# ...
# 100% 22.8M/22.8M [00:00<00:00, 109MB/s]
# Ultralytics 8.3.85 🚀 Python-3.11.11 torch-2.5.1+cu124 CUDA:0 (Tesla T4, 15095MiB)
# ...

# %%
# !yolo task=segment mode=val model="/content/runs/segment/train/weights/best.pt" \
    data="/content/drive/MyDrive/YOLO_D/data.yaml"
# Out:
# Ultralytics 8.3.85 🚀 Python-3.11.11 torch-2.5.1+cu124 CUDA:0 (Tesla T4, 15095MiB)
# YOLOv8n-seg summary (fused): 85 layers, 3,258,259 parameters, 0 gradients, 12.0 GFLOPs
# val: Scanning /content/drive/MyDrive/YOLO_D/valid/labels.cache... 468 images, 20 backgrounds, 0 corrupt: 100% 468/468 [00:00<?, ?it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% 30/30 [00:12<00:00,  2.43it/s]
#                    all        468        816       0.65      0.616      0.629      0.464      0.642      0.607      0.612      0.419
# Speed: 0.9ms preprocess, 6.5ms inference, 0.0ms loss, 3.1ms postprocess per image
# Results saved to runs/segment/val
# 💡 Learn more at https://docs.ultralytics.com/modes/val

# %%
import os
print(os.listdir("/content/runs/segment/train/weights/"))
# Out:
# ['best.pt', 'last.pt']

# %%
# !find /content/ -name "*.pt"
# Out:
# /content/yolov8s-seg.pt
# /content/yolo11n.pt
# /content/runs/segment/train2/weights/best.pt
# /content/runs/segment/train2/weights/last.pt
# /content/runs/segment/train/weights/best.pt
# /content/runs/segment/train/weights/last.pt
# /content/yolov8n-seg.pt
# /content/drive/MyDrive/yolov8n-seg.pt
# /content/drive/MyDrive/YOLO_D/ yolov8n-seg.pt
# /content/drive/MyDrive/YOLO_D/yolov8n1.pt
# /content/drive/MyDrive/YOLO_D/yolov8n-seg.pt

# %%
# !cp -r /content/runs/segment/train/weights /content/drive/MyDrive/YOLO_D/

# %%
# !yolo task=segment mode=predict model="/content/runs/segment/train/weights/best.pt" \
    source="/content/drive/MyDrive/YOLO_D/casa.png"
# Out:
# Ultralytics 8.3.85 🚀 Python-3.11.11 torch-2.5.1+cu124 CUDA:0 (Tesla T4, 15095MiB)
# YOLOv8n-seg summary (fused): 85 layers, 3,258,259 parameters, 0 gradients, 12.0 GFLOPs
#
# image 1/1 /content/drive/MyDrive/YOLO_D/casa.png: 352x640 1 vac_land, 49.3ms
# Speed: 3.3ms preprocess, 49.3ms inference, 169.2ms postprocess per image at shape (1, 3, 352, 640)
# Results saved to runs/segment/predict
# 💡 Learn more at https://docs.ultralytics.com/modes/predict

# %%
import os
print(os.listdir("/content/runs/segment/predict/"))
# Out:
# ['casa.jpg']

# %%
# !cp -r /content/runs/segment/predict /content/drive/MyDrive/YOLO_D/
